# %%
# Exercise 3 — Email Histogram

from pathlib import Path

# Ask user for file name
fname = input("Enter file name: ")

# If user just presses Enter, use default file
if len(fname) < 1:
    fname = "mbox-short.txt"

# Build correct path (chap_09 → parent → files folder)
BASE_DIR = Path.cwd().parent
file_path = BASE_DIR / "files" / fname

# Open the file for reading
handle = open(file_path)

# Dictionary to store email → count
counts = {}

for line in handle:

    # Only process real email lines
    if line.startswith("From "):

        words = line.split()

        # Email address is the second word
        email = words[1]

        # Count how many times this email appears
        counts[email] = counts.get(email, 0) + 1

# Print full dictionary of email counts
print(counts)
